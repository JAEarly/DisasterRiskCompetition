# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#kfold_acc = [0.7889784946236559, 0.7943548387096774, 0.7963709677419355, 0.7950268817204301, 0.7970430107526881, 0.793010752688172, 0.8010752688172043, 0.7916666666666666, 0.7990591397849462]
#kfold_loss = [0.5484363907526131, 0.545032142948971, 0.5609353235164157, 0.542881593218715, 0.5425315752316149, 0.5522980161052352, 0.545423538928013, 0.54210602378106, 0.540762841471024]
kfold_acc = [0.8015232974910393, 0.8006272401433692, 0.8055555555555555, 0.8055555555555557, 0.8055555555555555]
kfold_loss = [0.5362190707251021, 0.5344454392532199, 0.5299818774412715, 0.5257316997313901, 0.5272974102536933]
k = 5
x = range(1, k+1)

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 5))
axes[0].plot(x, kfold_acc)
axes[0].set_xlim(1, k)
axes[0].set_xlabel('k')
axes[0].set_ylabel('Acc')

axes[1].plot(x, kfold_loss)
axes[1].set_xlim(1, k)
axes[1].set_xlabel('k')
axes[1].set_ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')
