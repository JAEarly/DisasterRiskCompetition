# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
kfold_acc = [0.8030913978494624, 0.8299731182795699, 0.8279569892473119, 0.8286290322580645, 0.8293010752688172, 0.834005376344086, 0.8293010752688172, 0.8299731182795699]
kfold_loss = [0.549530517068311, 0.44900748479087405, 0.44959637525576535, 0.4496705759196512, 0.45036853909472463, 0.449968776474106, 0.4517273590549506, 0.4502720162297489]
k = len(kfold_acc)
x = range(1, k+1)

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 5))
axes[0].plot(x, kfold_acc)
axes[0].set_xlim(1, k)
axes[0].set_xlabel('k')
axes[0].set_ylabel('Acc')

axes[1].plot(x, kfold_loss)
axes[1].set_xlim(1, k)
axes[1].set_xlabel('k')
axes[1].set_ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')
